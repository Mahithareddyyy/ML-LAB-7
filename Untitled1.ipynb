# %%
import numpy as np
import pandas as pd
df=pd.read_excel("embeddingsdata.xlsx")
df
# Out:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.019743 -0.071799  0.022546  0.049042 -0.005767 -0.016275 -0.037731
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
# 897  0.018066 -0.032152  0.039794  0.047608  0.003898  0.024092 -0.056508
# 898 -0.003492 -0.022739  0.021777  0.044054 -0.005621  0.013863 -0.079196
# 899  0.013689 -0.037855  0.039763  0.035750  0.004115  0.005637 -0.050556
#
#       embed_7   embed_8   embed_9  ...  embed_759  embed_760  embed_761  \
# ...

# %%
#A1
import numpy as np
from sklearn.model_selection import train_test_split
# Select any two classes from the dataset
class_A = 2
class_B = 5
#I selected class 2 and 5
X = df.drop(['Label'], axis=1)  #Here we are dropping the target label column and including all the rest of the features
y = df['Label']  #We are taking all the attributes of target label column
# Filtering the data to include only the selected classes i.e. class having label as 2 and class having label as 5
X_selected = X[(y == class_A) | (y == class_B)]
y_selected = y[(y == class_A) | (y == class_B)]
# Splitting the data into a training set and a testing set
X_train, X_test, y_train, y_test = train_test_split(X_selected, y_selected, test_size=0.2, random_state=42)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train, y_train)
#Printing the support vectors
clf.support_vectors_
# Out:
# array([[ 0.02388904, -0.04063231,  0.04177761, ...,  0.01855134,
#         -0.00669768, -0.03682343],
#        [ 0.01502744, -0.02819995,  0.01737051, ..., -0.00945718,
#         -0.02375693, -0.01807858],
#        [ 0.01272665, -0.03244087,  0.01450373, ...,  0.01220417,
#          0.00093367, -0.03449239],
#        ...,
#        [ 0.01187808,  0.00566622,  0.01688203, ...,  0.01273762,
#         -0.02401946, -0.02839365],
#        [ 0.01147144,  0.00647764,  0.01864854, ...,  0.00375478,
#         -0.03079517, -0.02141507],
#        [ 0.00551515, -0.02375253,  0.03383914, ...,  0.0045059 ,
#         -0.01476743, -0.02711119]])

# %%
#A2
# Calculating the accuracy of the SVM on the test set
accuracy = clf.score(X_test, y_test)
print("Accuracy:", accuracy)
# Performing classification for the given test vector
test_vector = X_test[df.drop(['Label'], axis=1)].iloc[0]
predicted_class = clf.predict([test_vector])
print(f"The predicted class for the test vector: {predicted_class}")
# Out:
# Accuracy: 0.6857142857142857
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5264\1258085659.py in ?()
#       2 # Calculating the accuracy of the SVM on the test set
#       3 accuracy = clf.score(X_test, y_test)
#       4 print("Accuracy:", accuracy)
#       5 # Performing classification for the given test vector
# ----> 6 test_vector = X_test[df.drop(['Label'], axis=1)].iloc[0]
#       7 predicted_class = clf.predict([test_vector])
#       8 print(f"The predicted class for the test vector: {predicted_class}")
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    3744             return self._slice(indexer, axis=0)
#    3745
#    3746         # Do we have a (boolean) DataFrame?
#    3747         if isinstance(key, DataFrame):
# -> 3748             return self.where(key)
#    3749
# ...
